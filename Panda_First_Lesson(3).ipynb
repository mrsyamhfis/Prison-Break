# %% [markdown]
# <a href="https://colab.research.google.com/github/mrsyamhfis/Python_Exercise_Projects/blob/main/Copy_of_Panda_First_Lesson(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/used_car_ads.csv")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (7,8,10,11,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.head(10)
# Out:
#    maker    model   mileage  manufacture_year  engine_displacement  \
# 0   ford   galaxy  151000.0            2011.0               2000.0
# 1  skoda  octavia  143476.0            2012.0               2000.0
# 2    bmw      NaN   97676.0            2010.0               1995.0
# 3  skoda    fabia  111970.0            2004.0               1200.0
# 4  skoda    fabia  128886.0            2004.0               1200.0
# 5  skoda    fabia  140932.0            2003.0               1200.0
# 6  skoda    fabia  167220.0            2001.0               1400.0
# 7    bmw      NaN  148500.0            2009.0               2000.0
# 8  skoda  octavia  105389.0            2003.0               1900.0
# 9    NaN      NaN  301381.0            2002.0               1900.0
#
#    engine_power body_type color_slug stk_year transmission door_count  \
# 0         103.0       NaN        NaN     None          man          5
# 1          81.0       NaN        NaN     None          man          5
# ...

# %%
df.manufacture_year
# Out:
# 0          2011.0
# 1          2012.0
# 2          2010.0
# 3          2004.0
# 4          2004.0
#             ...
# 3552907    2013.0
# 3552908    2000.0
# 3552909    2006.0
# 3552910    2001.0
# 3552911       NaN
# Name: manufacture_year, Length: 3552912, dtype: float64

# %%
df.maker
# Out:
# 0                   ford
# 1                  skoda
# 2                    bmw
# 3                  skoda
# 4                  skoda
#                ...
# 3552907            skoda
# 3552908            skoda
# 3552909            skoda
# 3552910            skoda
# 3552911    mercedes-benz
# Name: maker, Length: 3552912, dtype: object

# %%
df.columns
# Out:
# Index(['maker', 'model', 'mileage', 'manufacture_year', 'engine_displacement',
#        'engine_power', 'body_type', 'color_slug', 'stk_year', 'transmission',
#        'door_count', 'seat_count', 'fuel_type', 'date_created',
#        'date_last_seen', 'price_eur'],
#       dtype='object')

# %%
df.maker[3552910]
# Out:
# 'skoda'

# %% [markdown]
# ## Inspecting your data:

# %%
df.loc[0,"maker"]
# Out:
# 'ford'

# %%
df.loc[:,"maker"]
# Out:
# 0                   ford
# 1                  skoda
# 2                    bmw
# 3                  skoda
# 4                  skoda
#                ...
# 3552907            skoda
# 3552908            skoda
# 3552909            skoda
# 3552910            skoda
# 3552911    mercedes-benz
# Name: maker, Length: 3552912, dtype: object

# %%
df.loc[0:10, ["maker","model"]]
# Out:
#     maker    model
# 0    ford   galaxy
# 1   skoda  octavia
# 2     bmw      NaN
# 3   skoda    fabia
# 4   skoda    fabia
# 5   skoda    fabia
# 6   skoda    fabia
# 7     bmw      NaN
# 8   skoda  octavia
# 9     NaN      NaN
# 10    NaN      NaN

# %%
df.iloc[0:10, :2]
# Out:
#    maker    model
# 0   ford   galaxy
# 1  skoda  octavia
# 2    bmw      NaN
# 3  skoda    fabia
# 4  skoda    fabia
# 5  skoda    fabia
# 6  skoda    fabia
# 7    bmw      NaN
# 8  skoda  octavia
# 9    NaN      NaN

# %%
df.head(4)
# Out:
#    maker    model   mileage  manufacture_year  engine_displacement  \
# 0   ford   galaxy  151000.0            2011.0               2000.0
# 1  skoda  octavia  143476.0            2012.0               2000.0
# 2    bmw      NaN   97676.0            2010.0               1995.0
# 3  skoda    fabia  111970.0            2004.0               1200.0
#
#    engine_power body_type color_slug stk_year transmission door_count  \
# 0         103.0       NaN        NaN     None          man          5
# 1          81.0       NaN        NaN     None          man          5
# 2          85.0       NaN        NaN     None          man          5
# 3          47.0       NaN        NaN     None          man          5
#
#   seat_count fuel_type                   date_created  \
# 0          7    diesel  2015-11-14 18:10:06.838319+00
# 1          5    diesel  2015-11-14 18:10:06.853411+00
# 2          5    diesel  2015-11-14 18:10:06.861792+00
# 3          5  gasoline  2015-11-14 18:10:06.872313+00
#
# ...

# %%
df.describe()
# Out:
#             mileage  manufacture_year  engine_displacement  engine_power  \
# count  3.190328e+06      3.182334e+06         2.809498e+06  2.998035e+06
# mean   1.158140e+05      2.000871e+03         2.043958e+03  9.846796e+01
# std    3.422508e+05      8.172588e+01         1.973958e+03  4.907309e+01
# min    0.000000e+00      0.000000e+00         0.000000e+00  1.000000e+00
# 25%    1.880000e+04      2.004000e+03         1.400000e+03  6.800000e+01
# 50%    8.641500e+04      2.009000e+03         1.798000e+03  8.600000e+01
# 75%    1.580250e+05      2.013000e+03         1.997000e+03  1.100000e+02
# max    9.999999e+06      2.017000e+03         3.276700e+04  2.237000e+03
#
#           price_eur
# count  3.552912e+06
# mean   1.625812e+06
# std    2.025622e+09
# min    4.000000e-02
# 25%    1.295340e+03
# 50%    7.364910e+03
# 75%    1.628423e+04
# max    2.706149e+12

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3552912 entries, 0 to 3552911
# Data columns (total 16 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   maker                object
#  1   model                object
#  2   mileage              float64
#  3   manufacture_year     float64
#  4   engine_displacement  float64
#  5   engine_power         float64
#  6   body_type            object
#  7   color_slug           object
#  8   stk_year             object
#  9   transmission         object
#  10  door_count           object
#  11  seat_count           object
#  12  fuel_type            object
#  13  date_created         object
#  14  date_last_seen       object
#  15  price_eur            float64
# dtypes: float64(5), object(11)
# memory usage: 433.7+ MB

# %%
df.shape #(rows, columns)
# Out:
# (3552912, 16)

# %%
df.maker.describe()
# Out:
# count     3033997
# unique         46
# top         skoda
# freq       313830
# Name: maker, dtype: object

# %%
df.maker.unique()
# Out:
# array(['ford', 'skoda', 'bmw', nan, 'suzuki', 'nissan', 'opel', 'citroen',
#        'seat', 'kia', 'audi', 'rover', 'toyota', 'hyundai', 'fiat',
#        'volvo', 'chevrolet', 'mazda', 'jeep', 'mercedes-benz', 'subaru',
#        'chrysler', 'lancia', 'smart', 'honda', 'porsche', 'dodge',
#        'mitsubishi', 'mini', 'jaguar', 'lexus', 'hummer', 'bentley',
#        'tesla', 'maserati', 'isuzu', 'lamborghini', 'lotus', 'volkswagen',
#        'peugeot', 'renault', 'alfa-romeo', 'infinity', 'rolls-royce',
#        'aston-martin', 'land-rover', 'dacia'], dtype=object)

# %%
df.maker.value_counts()
# Out:
# skoda            313830
# volkswagen       297256
# bmw              266731
# mercedes-benz    251966
# audi             248602
# ford             240556
# opel             217708
# fiat             132669
# citroen          121913
# renault          106831
# peugeot           92130
# hyundai           80602
# seat              74645
# toyota            72908
# nissan            68008
# kia               48607
# volvo             48271
# mazda             45666
# mini              35678
# smart             32918
# suzuki            31184
# mitsubishi        28463
# honda             26225
# porsche           24317
# chevrolet         20856
# rover             20611
# jeep              17075
# lancia            13759
# subaru            10107
# jaguar            10056
# chrysler           9296
# dodge              5223
# alfa-romeo         4734
# lexus              3911
# dacia              2024
# maserati           1912
# land-rover         1721
# isuzu              1427
# ...

# %%
df.mileage.max()
# Out:
# 9999999.0

# %%
df.maker == 'skoda'
# Out:
# 0          False
# 1           True
# 2          False
# 3           True
# 4           True
#            ...
# 3552907     True
# 3552908     True
# 3552909     True
# 3552910     True
# 3552911    False
# Name: maker, Length: 3552912, dtype: bool

# %%
df[df.maker == 'skoda']
# Out:
#          maker     model   mileage  manufacture_year  engine_displacement  \
# 1        skoda   octavia  143476.0            2012.0               2000.0
# 3        skoda     fabia  111970.0            2004.0               1200.0
# 4        skoda     fabia  128886.0            2004.0               1200.0
# 5        skoda     fabia  140932.0            2003.0               1200.0
# 6        skoda     fabia  167220.0            2001.0               1400.0
# ...        ...       ...       ...               ...                  ...
# 3552906  skoda   octavia  168000.0            1999.0                  NaN
# 3552907  skoda  roomster   54000.0            2013.0               1200.0
# 3552908  skoda   felicia       NaN            2000.0                  NaN
# 3552909  skoda   octavia  230000.0            2006.0               1900.0
# 3552910  skoda     fabia       NaN            2001.0                  NaN
#
#          engine_power body_type color_slug stk_year transmission door_count  \
# ...

# %%
df.loc[(df.maker == 'skoda') | (df.maker == 'ford')]
# Out:
#          maker     model   mileage  manufacture_year  engine_displacement  \
# 0         ford    galaxy  151000.0            2011.0               2000.0
# 1        skoda   octavia  143476.0            2012.0               2000.0
# 3        skoda     fabia  111970.0            2004.0               1200.0
# 4        skoda     fabia  128886.0            2004.0               1200.0
# 5        skoda     fabia  140932.0            2003.0               1200.0
# ...        ...       ...       ...               ...                  ...
# 3552906  skoda   octavia  168000.0            1999.0                  NaN
# 3552907  skoda  roomster   54000.0            2013.0               1200.0
# 3552908  skoda   felicia       NaN            2000.0                  NaN
# 3552909  skoda   octavia  230000.0            2006.0               1900.0
# 3552910  skoda     fabia       NaN            2001.0                  NaN
#
#          engine_power body_type color_slug stk_year transmission door_count  \
# ...

# %%
df[df.maker.isin(['skoda','ford'])] #without using 'or' and 'and' commands
# Out:
#          maker     model   mileage  manufacture_year  engine_displacement  \
# 0         ford    galaxy  151000.0            2011.0               2000.0
# 1        skoda   octavia  143476.0            2012.0               2000.0
# 3        skoda     fabia  111970.0            2004.0               1200.0
# 4        skoda     fabia  128886.0            2004.0               1200.0
# 5        skoda     fabia  140932.0            2003.0               1200.0
# ...        ...       ...       ...               ...                  ...
# 3552906  skoda   octavia  168000.0            1999.0                  NaN
# 3552907  skoda  roomster   54000.0            2013.0               1200.0
# 3552908  skoda   felicia       NaN            2000.0                  NaN
# 3552909  skoda   octavia  230000.0            2006.0               1900.0
# 3552910  skoda     fabia       NaN            2001.0                  NaN
#
#          engine_power body_type color_slug stk_year transmission door_count  \
# ...

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ### Renaming and dropping columns

# %%
df.rename(columns={"mileage" : "mileage_in_miles", "maker" : "car_maker"}, inplace=True)

# %%
df.head()
# Out:
#   car_maker    model  mileage_in_miles  manufacture_year  engine_displacement  \
# 0      ford   galaxy          151000.0            2011.0               2000.0
# 1     skoda  octavia          143476.0            2012.0               2000.0
# 2       bmw      NaN           97676.0            2010.0               1995.0
# 3     skoda    fabia          111970.0            2004.0               1200.0
# 4     skoda    fabia          128886.0            2004.0               1200.0
#
#    engine_power body_type color_slug stk_year transmission door_count  \
# 0         103.0       NaN        NaN     None          man          5
# 1          81.0       NaN        NaN     None          man          5
# 2          85.0       NaN        NaN     None          man          5
# 3          47.0       NaN        NaN     None          man          5
# 4          47.0       NaN        NaN     None          man          5
#
#   seat_count fuel_type                   date_created  \
# ...

# %% [markdown]
# notes : df.iloc[0,0] ---> axis[0,1]=[ROW,COLUMN]

# %%
df.drop(['mileage_in_miles','car_maker'],axis=1, inplace=True)

# %%
df.head()
# Out:
#      model  manufacture_year  engine_displacement  engine_power body_type  \
# 0   galaxy            2011.0               2000.0         103.0       NaN
# 1  octavia            2012.0               2000.0          81.0       NaN
# 2      NaN            2010.0               1995.0          85.0       NaN
# 3    fabia            2004.0               1200.0          47.0       NaN
# 4    fabia            2004.0               1200.0          47.0       NaN
#
#   color_slug stk_year transmission door_count seat_count fuel_type  \
# 0        NaN     None          man          5          7    diesel
# 1        NaN     None          man          5          5    diesel
# 2        NaN     None          man          5          5    diesel
# 3        NaN     None          man          5          5  gasoline
# 4        NaN     None          man          5          5  gasoline
#
#                     date_created                date_last_seen  price_eur
# ...
