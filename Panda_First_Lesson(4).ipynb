# %% [markdown]
# <a href="https://colab.research.google.com/github/mrsyamhfis/Python_Exercise_Projects/blob/main/Panda_First_Lesson(5).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/used_car_ads.csv")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (7,8,10,11,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# Manipulating strings

# %%
df.maker=df.maker.str.lower() #lowercase

# %%
df.maker=df.maker.str.upper() #uppercase

# %%
df.maker=df.maker.str.capitalize()

# %%
df.head()
# Out:
#    maker    model   mileage  manufacture_year  engine_displacement  \
# 0   Ford   galaxy  151000.0            2011.0               2000.0
# 1  Skoda  octavia  143476.0            2012.0               2000.0
# 2    Bmw      NaN   97676.0            2010.0               1995.0
# 3  Skoda    fabia  111970.0            2004.0               1200.0
# 4  Skoda    fabia  128886.0            2004.0               1200.0
#
#    engine_power body_type color_slug stk_year transmission door_count  \
# 0         103.0       NaN        NaN     None          man          5
# 1          81.0       NaN        NaN     None          man          5
# 2          85.0       NaN        NaN     None          man          5
# 3          47.0       NaN        NaN     None          man          5
# 4          47.0       NaN        NaN     None          man          5
#
#   seat_count fuel_type                   date_created  \
# 0          7    diesel  2015-11-14 18:10:06.838319+00
# ...

# %%
df.maker=df.maker.str.strip() #strip white space

# %% [markdown]
# Taking strip command a little further

# %%
df['URl']= 'https://theuselessweb.com/'

# %%
df.head()
# Out:
#    maker    model   mileage  manufacture_year  engine_displacement  \
# 0   Ford   galaxy  151000.0            2011.0               2000.0
# 1  Skoda  octavia  143476.0            2012.0               2000.0
# 2    Bmw      NaN   97676.0            2010.0               1995.0
# 3  Skoda    fabia  111970.0            2004.0               1200.0
# 4  Skoda    fabia  128886.0            2004.0               1200.0
#
#    engine_power body_type color_slug stk_year transmission door_count  \
# 0         103.0       NaN        NaN     None          man          5
# 1          81.0       NaN        NaN     None          man          5
# 2          85.0       NaN        NaN     None          man          5
# 3          47.0       NaN        NaN     None          man          5
# 4          47.0       NaN        NaN     None          man          5
#
#   seat_count fuel_type                   date_created  \
# 0          7    diesel  2015-11-14 18:10:06.838319+00
# ...

# %%
df['website name']= df.URl.str.lstrip('https://') #left

# %%
df.head()
# Out:
#    maker    model   mileage  manufacture_year  engine_displacement  \
# 0   Ford   galaxy  151000.0            2011.0               2000.0
# 1  Skoda  octavia  143476.0            2012.0               2000.0
# 2    Bmw      NaN   97676.0            2010.0               1995.0
# 3  Skoda    fabia  111970.0            2004.0               1200.0
# 4  Skoda    fabia  128886.0            2004.0               1200.0
#
#    engine_power body_type color_slug stk_year transmission door_count  \
# 0         103.0       NaN        NaN     None          man          5
# 1          81.0       NaN        NaN     None          man          5
# 2          85.0       NaN        NaN     None          man          5
# 3          47.0       NaN        NaN     None          man          5
# 4          47.0       NaN        NaN     None          man          5
#
#   seat_count fuel_type                   date_created  \
# 0          7    diesel  2015-11-14 18:10:06.838319+00
# ...

# %%
df['website name']= df.URl.str.rstrip('.com/') #right

# %% [markdown]
# Concatenate strings

# %%
df['maker_and_model'] = df.maker + ' ' + df.model

# %%
df.head()
# Out:
#    maker    model   mileage  manufacture_year  engine_displacement  \
# 0   Ford   galaxy  151000.0            2011.0               2000.0
# 1  Skoda  octavia  143476.0            2012.0               2000.0
# 2    Bmw      NaN   97676.0            2010.0               1995.0
# 3  Skoda    fabia  111970.0            2004.0               1200.0
# 4  Skoda    fabia  128886.0            2004.0               1200.0
#
#    engine_power body_type color_slug stk_year transmission door_count  \
# 0         103.0       NaN        NaN     None          man          5
# 1          81.0       NaN        NaN     None          man          5
# 2          85.0       NaN        NaN     None          man          5
# 3          47.0       NaN        NaN     None          man          5
# 4          47.0       NaN        NaN     None          man          5
#
#   seat_count fuel_type                   date_created  \
# 0          7    diesel  2015-11-14 18:10:06.838319+00
# ...

# %% [markdown]
# Manipulate strings

# %%
df["manufacture_year"] = df["manufacture_year"].astype(str)

# %%
df["manufacture_year"] = df.manufacture_year.str[:4]

# %%
df.head()
# Out:
#    maker    model   mileage manufacture_year  engine_displacement  \
# 0   Ford   galaxy  151000.0             2011               2000.0
# 1  Skoda  octavia  143476.0             2012               2000.0
# 2    Bmw      NaN   97676.0             2010               1995.0
# 3  Skoda    fabia  111970.0             2004               1200.0
# 4  Skoda    fabia  128886.0             2004               1200.0
#
#    engine_power body_type color_slug stk_year transmission door_count  \
# 0         103.0       NaN        NaN     None          man          5
# 1          81.0       NaN        NaN     None          man          5
# 2          85.0       NaN        NaN     None          man          5
# 3          47.0       NaN        NaN     None          man          5
# 4          47.0       NaN        NaN     None          man          5
#
#   seat_count fuel_type                   date_created  \
# 0          7    diesel  2015-11-14 18:10:06.838319+00
# ...
