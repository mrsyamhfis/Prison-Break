# %% [markdown]
# <a href="https://colab.research.google.com/github/mrsyamhfis/Python_Exercise_Projects/blob/main/Panda_First_Lesson(6).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/used_car_ads.csv")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (7,8,10,11,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.head()
# Out:
#    maker    model   mileage  manufacture_year  engine_displacement  \
# 0   ford   galaxy  151000.0            2011.0               2000.0
# 1  skoda  octavia  143476.0            2012.0               2000.0
# 2    bmw      NaN   97676.0            2010.0               1995.0
# 3  skoda    fabia  111970.0            2004.0               1200.0
# 4  skoda    fabia  128886.0            2004.0               1200.0
#
#    engine_power body_type color_slug stk_year transmission door_count  \
# 0         103.0       NaN        NaN     None          man          5
# 1          81.0       NaN        NaN     None          man          5
# 2          85.0       NaN        NaN     None          man          5
# 3          47.0       NaN        NaN     None          man          5
# 4          47.0       NaN        NaN     None          man          5
#
#   seat_count fuel_type                   date_created  \
# 0          7    diesel  2015-11-14 18:10:06.838319+00
# ...

# %% [markdown]
# Sort columns

# %%
df.sort_values(by=['mileage','manufacture_year'], ascending = True, inplace = True)

# %%
df.head()
# Out:
#               maker        model  mileage  manufacture_year  \
# 3183095        ford  grand-c-max      0.0               0.0
# 3197074       skoda        fabia      0.0               0.0
# 3241481     citroen    c4-cactus      0.0               0.0
# 3268840     citroen    c4-cactus      0.0               0.0
# 3147843  volkswagen         golf      0.0               4.0
#
#          engine_displacement  engine_power body_type color_slug stk_year  \
# 3183095               1596.0         110.0     other        NaN   2018.0
# 3197074               1600.0          66.0     other        NaN      NaN
# 3241481                  NaN           NaN     other        NaN      NaN
# 3268840                  NaN           NaN     other        NaN      NaN
# 3147843               7100.0          77.0     other        NaN   2017.0
#
#         transmission door_count seat_count fuel_type  \
# 3183095          man        NaN        NaN  gasoline
# 3197074          man        NaN        NaN    diesel
# ...

# %% [markdown]
# Concatenate text

# %%
df['Enriching Data']= df.mileage + df.mileage.max()

# %%
df.head()
# Out:
#               maker        model  mileage  manufacture_year  \
# 3183095        ford  grand-c-max      0.0               0.0
# 3197074       skoda        fabia      0.0               0.0
# 3241481     citroen    c4-cactus      0.0               0.0
# 3268840     citroen    c4-cactus      0.0               0.0
# 3147843  volkswagen         golf      0.0               4.0
#
#          engine_displacement  engine_power body_type color_slug stk_year  \
# 3183095               1596.0         110.0     other        NaN   2018.0
# 3197074               1600.0          66.0     other        NaN      NaN
# 3241481                  NaN           NaN     other        NaN      NaN
# 3268840                  NaN           NaN     other        NaN      NaN
# 3147843               7100.0          77.0     other        NaN   2017.0
#
#         transmission door_count seat_count fuel_type  \
# 3183095          man        NaN        NaN  gasoline
# 3197074          man        NaN        NaN    diesel
# ...

# %% [markdown]
# Saving dataframe

# %%
df.to_csv('cleaned_dataset.csv') #index=False(if dont want to include index)
