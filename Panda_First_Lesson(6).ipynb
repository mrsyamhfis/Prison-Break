# %% [markdown]
# <a href="https://colab.research.google.com/github/mrsyamhfis/Python_Exercise_Projects/blob/main/CH_Panda_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
test_df = pd.read_csv('/content/sample_data/california_housing_train.csv')

# %%
test_df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
test_df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
test_df.drop(['longitude','latitude'], axis=1)
# Out:
#        housing_median_age  total_rooms  total_bedrooms  population  \
# 0                    15.0       5612.0          1283.0      1015.0
# 1                    19.0       7650.0          1901.0      1129.0
# 2                    17.0        720.0           174.0       333.0
# 3                    14.0       1501.0           337.0       515.0
# 4                    20.0       1454.0           326.0       624.0
# ...                   ...          ...             ...         ...
# 16995                52.0       2217.0           394.0       907.0
# 16996                36.0       2349.0           528.0      1194.0
# 16997                17.0       2677.0           531.0      1244.0
# 16998                19.0       2672.0           552.0      1298.0
# 16999                52.0       1820.0           300.0       806.0
#
#        households  median_income  median_house_value
# 0           472.0         1.4936             66900.0
# 1           463.0         1.8200             80100.0
# ...

# %%
test_df.isnull()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0          False     False               False        False           False
# 1          False     False               False        False           False
# 2          False     False               False        False           False
# 3          False     False               False        False           False
# 4          False     False               False        False           False
# ...          ...       ...                 ...          ...             ...
# 16995      False     False               False        False           False
# 16996      False     False               False        False           False
# 16997      False     False               False        False           False
# 16998      False     False               False        False           False
# 16999      False     False               False        False           False
#
# ...

# %%
test_df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
pd.value_counts(test_df['housing_median_age']).plot.bar()

# %%
test_df['total_rooms'].mean()
# Out:
# 2643.664411764706

# %%
test_df.groupby(['median_income']).mean()
# Out:
#                 longitude   latitude  housing_median_age  total_rooms  \
# median_income
# 0.4999        -119.885455  36.381818           33.909091   224.181818
# 0.5360        -119.687143  35.934286           30.428571    58.285714
# 0.6433        -117.120000  32.710000           24.000000   421.000000
# 0.6775        -118.250000  34.050000           52.000000  2806.000000
# 0.6825        -121.000000  37.650000           17.000000   484.000000
# ...                   ...        ...                 ...          ...
# 14.4219       -122.350000  37.560000           52.000000  1659.000000
# 14.5833       -122.520000  37.920000           24.000000   421.000000
# 14.9009       -117.680000  33.590000            8.000000  2327.000000
# 15.0000       -121.980000  37.250000           19.000000   755.000000
# 15.0001       -119.607895  35.185789           40.105263  2313.236842
#
#                total_bedrooms   population   households  median_house_value
# median_income
# ...

# %%
test_df['population'].plot()

# %%
test_df.index
# Out:
# RangeIndex(start=0, stop=17000, step=1)

# %%
test_df.info
# Out:
# <bound method DataFrame.info of        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...
